# %%
import sys
import os
from fastapi import FastAPI
import uvicorn
import nest_asyncio

# 🔹 Ensure Jupyter can find the 'backend' folder
sys.path.append(os.path.abspath("../AI"))

from heart_rate import get_bpm  # ✅ Import from heart_rate.py

# 🔹 Initialize FastAPI
app = FastAPI()

# 🔹 Define API routes
@app.get("/")
def read_root():
    return {"message": "Welcome to Heart Rate API"}

@app.get("/bpm")
def bpm():
    return get_bpm()

# 🔹 Fix event loop issue for FastAPI in Jupyter Notebook
nest_asyncio.apply()

# 🔹 Run FastAPI server (only run once!)
uvicorn.run(app, host="0.0.0.0", port=8000, reload=False)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 10
#       7 # 🔹 Ensure Jupyter can find the 'backend' folder
#       8 sys.path.append(os.path.abspath("../AI"))
# ---> 10 from heart_rate import get_bpm  # ✅ Import from heart_rate.py
#      12 # 🔹 Initialize FastAPI
#      13 app = FastAPI()
#
# ModuleNotFoundError: No module named 'heart_rate'
