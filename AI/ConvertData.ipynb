# %%
import pandas as pd

# Load the Excel file
df = pd.read_excel('C:/Users/bchal/OneDrive/Documents/stage pfe master/MindCare-AI/liste_amm.xls')  # replace with your file name

# Convert to JSON and save
df.to_json('C:/Users/bchal/OneDrive/Documents/stage pfe master/MindCare-AI/Medicament.json', orient='records', force_ascii=False, indent=4)

print("Conversion done! Saved as Medicament.json.")
# Out:
# Conversion done! Saved as output.json.
